# %%
import os, numpy as np, librosa, tflearn

# %%
def LABEL_AL_FATIHA(filename):
    ayah = int(filename[5])
    return np.eye(8)[ayah]

# %%
PATH_TRAIN = './dataset/train/'
DATA_TRAIN = [x for x in os.listdir(PATH_TRAIN) if x.endswith('.wav')]
MAX_PAD = 2149
MFCCS = list()
LABELS = list()

# %%
for x in DATA_TRAIN:
    y, sr = librosa.load(PATH_TRAIN + x, sr=None, mono=True)
    emphasized_signal = np.append(y[0], y[1:] - 0.97 * y[:-1])
    mfcc = librosa.feature.mfcc(emphasized_signal, sr)
    mfcc = np.pad(mfcc, ((0,0), (0,MAX_PAD-len(mfcc[0]))), mode='constant', constant_values=0)
    LABELS.append(LABEL_AL_FATIHA(x))
    MFCCS.append(np.array(mfcc))
    print(x + ' done.')
    #if MAX_PAD < mfcc.shape[1]:
    #    MAX_PAD = mfcc.shape[1]
# Out:
# 001006_Abdullah_Matroud_128kbps.wav done.
# 001001_ahmed_ibn_ali_al_ajamy_128kbps.wav done.
# 001006_Alafasy_64kbps.wav done.
# 001005_Akram_AlAlaqimy_128kbps.wav done.
# 001004_ahmed_ibn_ali_al_ajamy_128kbps.wav done.
# 001002_aziz_alili_128kbps.wav done.
# 001003_Ahmed_ibn_Ali_al-Ajamy_64kbps.wav done.
# 001002_Ahmed_Neana_128kbps.wav done.
# 001002_Abdul_Basit_Murattal_64kbps.wav done.
# 001003_Abu_Bakr_Ash-Shaatree_128kbps.wav done.
# 001000_Abdullah_Basfar_192kbps.wav done.
# 001005_Abdurrahmaan_As-Sudais_64kbps.wav done.
# 001000_Abdurrahmaan_As-Sudais_64kbps.wav done.
# 001007_Abdullah_Matroud_128kbps.wav done.
# 001003_Abdurrahmaan_As-Sudais_64kbps.wav done.
# 001001_Abu_Bakr_Ash-Shaatree_128kbps.wav done.
# 001007_Abdullah_Basfar_64kbps.wav done.
# 001000_Abdurrahmaan_As-Sudais_192kbps.wav done.
# 001005_Abdul_Basit_Murattal_192kbps.wav done.
# 001002_Alafasy_128kbps.wav done.
# 001007_Abdul_Basit_Mujawwad_128kbps.wav done.
# 001007_Akram_AlAlaqimy_128kbps.wav done.
# 001002_Ahmed_ibn_Ali_al-Ajamy_128kbps.wav done.
# 001004_Abu_Bakr_Ash-Shaatree_128kbps.wav done.
# 001006_Abdurrahmaan_As-Sudais_192kbps.wav done.
# 001001_Abu_Bakr_Ash-Shaatree_64kbps.wav done.
# 001002_Akram_AlAlaqimy_128kbps.wav done.
# 001001_Akram_AlAlaqimy_128kbps.wav done.
# 001000_aziz_alili_128kbps.wav done.
# 001000_Ahmed_Neana_128kbps.wav done.
# 001002_Abdullah_Basfar_192kbps.wav done.
# 001004_Abdul_Basit_Murattal_64kbps.wav done.
# 001005_Abdul_Basit_Murattal_64kbps.wav done.
# 001007_Abdul_Basit_Murattal_64kbps.wav done.
# 001005_Alafasy_128kbps.wav done.
# 001005_Abdullaah_3awwaad_Al-Juhaynee_128kbps.wav done.
# 001001_aziz_alili_128kbps.wav done.
# 001001_Abdurrahmaan_As-Sudais_64kbps.wav done.
# 001002_Abdul_Basit_Murattal_192kbps.wav done.
# 001001_Abdul_Basit_Murattal_192kbps.wav done.
# 001006_aziz_alili_128kbps.wav done.
# 001001_Ali_Hajjaj_AlSuesy_128kbps.wav done.
# 001005_ahmed_ibn_ali_al_ajamy_128kbps.wav done.
# 001004_Abdullah_Basfar_32kbps.wav done.
# 001006_Ali_Hajjaj_AlSuesy_128kbps.wav done.
# 001001_Ahmed_Neana_128kbps.wav done.
# 001004_Akram_AlAlaqimy_128kbps.wav done.
# 001000_Abu_Bakr_Ash-Shaatree_64kbps.wav done.
# 001002_ahmed_ibn_ali_al_ajamy_128kbps.wav done.
# 001006_Abdullaah_3awwaad_Al-Juhaynee_128kbps.wav done.
# 001002_Abdurrahmaan_As-Sudais_64kbps.wav done.
# 001004_Abdullah_Basfar_64kbps.wav done.
# 001002_Abdullah_Basfar_64kbps.wav done.
# 001004_Abdul_Basit_Murattal_192kbps.wav done.
# 001004_Abdurrahmaan_As-Sudais_192kbps.wav done.
# 001000_Abdul_Basit_Murattal_64kbps.wav done.
# 001002_Abdullah_Matroud_128kbps.wav done.
# 001001_Abdullah_Basfar_64kbps.wav done.
# 001004_Abdul_Basit_Mujawwad_128kbps.wav done.
# 001004_Alafasy_64kbps.wav done.
# 001004_Abdullah_Matroud_128kbps.wav done.
# 001005_Ahmed_ibn_Ali_al-Ajamy_128kbps.wav done.
# 001005_Ahmed_ibn_Ali_al-Ajamy_64kbps.wav done.
# 001004_Abu_Bakr_Ash-Shaatree_64kbps.wav done.
# 001005_aziz_alili_128kbps.wav done.
# 001007_Ahmed_Neana_128kbps.wav done.
# 001007_Ahmed_ibn_Ali_al-Ajamy_64kbps.wav done.
# 001005_Abdul_Basit_Mujawwad_128kbps.wav done.
# 001006_Akram_AlAlaqimy_128kbps.wav done.
# 001003_Abdullah_Basfar_192kbps.wav done.
# 001002_Abdullah_Basfar_32kbps.wav done.
# 001003_Abdullah_Matroud_128kbps.wav done.
# 001003_Alafasy_128kbps.wav done.
# 001003_Akram_AlAlaqimy_128kbps.wav done.
# 001007_Abu_Bakr_Ash-Shaatree_128kbps.wav done.
# 001003_Abdullah_Basfar_64kbps.wav done.
# 001005_Alafasy_64kbps.wav done.
# 001005_Abdullah_Basfar_32kbps.wav done.
# 001003_ahmed_ibn_ali_al_ajamy_128kbps.wav done.
# 001006_Abdullah_Basfar_32kbps.wav done.
# 001001_Abdullah_Matroud_128kbps.wav done.
# 001003_Alafasy_64kbps.wav done.
# 001007_Ali_Hajjaj_AlSuesy_128kbps.wav done.
# 001003_Abdul_Basit_Murattal_64kbps.wav done.
# 001004_Abdurrahmaan_As-Sudais_64kbps.wav done.
# 001002_Abu_Bakr_Ash-Shaatree_64kbps.wav done.
# 001006_Abdul_Basit_Murattal_192kbps.wav done.
# 001000_Ahmed_ibn_Ali_al-Ajamy_128kbps.wav done.
# 001004_Abdullaah_3awwaad_Al-Juhaynee_128kbps.wav done.
# 001005_Abdullah_Basfar_64kbps.wav done.
# 001000_Abdullah_Matroud_128kbps.wav done.
# 001001_Abdul_Basit_Mujawwad_128kbps.wav done.
# 001007_Alafasy_64kbps.wav done.
# 001001_Abdullah_Basfar_192kbps.wav done.
# 001004_Ali_Hajjaj_AlSuesy_128kbps.wav done.
# 001006_Abdul_Basit_Murattal_64kbps.wav done.
# 001002_Abdurrahmaan_As-Sudais_192kbps.wav done.
# 001007_Abdurrahmaan_As-Sudais_64kbps.wav done.
# 001007_Abdul_Basit_Murattal_192kbps.wav done.
# 001001_Ahmed_ibn_Ali_al-Ajamy_128kbps.wav done.
# 001000_ahmed_ibn_ali_al_ajamy_128kbps.wav done.
# 001003_Abdul_Basit_Murattal_192kbps.wav done.
# 001003_Abdurrahmaan_As-Sudais_192kbps.wav done.
# 001000_Ali_Hajjaj_AlSuesy_128kbps.wav done.
# 001003_Ahmed_Neana_128kbps.wav done.
# 001005_Abdullah_Basfar_192kbps.wav done.
# 001001_Abdullaah_3awwaad_Al-Juhaynee_128kbps.wav done.
# 001006_Ahmed_ibn_Ali_al-Ajamy_128kbps.wav done.
# 001006_Abdullah_Basfar_192kbps.wav done.
# 001007_Ahmed_ibn_Ali_al-Ajamy_128kbps.wav done.
# 001006_Alafasy_128kbps.wav done.
# 001003_Ali_Hajjaj_AlSuesy_128kbps.wav done.
# 001006_Abdurrahmaan_As-Sudais_64kbps.wav done.
# 001000_Abdullaah_3awwaad_Al-Juhaynee_128kbps.wav done.
# 001007_Alafasy_128kbps.wav done.
# 001002_Abdullaah_3awwaad_Al-Juhaynee_128kbps.wav done.
# 001005_Abdullah_Matroud_128kbps.wav done.
# 001001_Ahmed_ibn_Ali_al-Ajamy_64kbps.wav done.
# 001006_Ahmed_ibn_Ali_al-Ajamy_64kbps.wav done.
# 001005_Ali_Hajjaj_AlSuesy_128kbps.wav done.
# 001006_Ahmed_Neana_128kbps.wav done.
# 001004_Abdullah_Basfar_192kbps.wav done.
# 001007_Abdullah_Basfar_192kbps.wav done.
# 001003_aziz_alili_128kbps.wav done.
# 001003_Abdullah_Basfar_32kbps.wav done.
# 001006_Abu_Bakr_Ash-Shaatree_128kbps.wav done.
# 001000_Ahmed_ibn_Ali_al-Ajamy_64kbps.wav done.
# 001005_Ahmed_Neana_128kbps.wav done.
# 001007_ahmed_ibn_ali_al_ajamy_128kbps.wav done.
# 001006_Abu_Bakr_Ash-Shaatree_64kbps.wav done.
# 001002_Alafasy_64kbps.wav done.
# 001003_Ahmed_ibn_Ali_al-Ajamy_128kbps.wav done.
# 001006_Abdullah_Basfar_64kbps.wav done.
# 001007_Abu_Bakr_Ash-Shaatree_64kbps.wav done.
# 001005_Abu_Bakr_Ash-Shaatree_64kbps.wav done.
# 001000_Akram_AlAlaqimy_128kbps.wav done.
# 001001_Abdul_Basit_Murattal_64kbps.wav done.
# 001001_Abdurrahmaan_As-Sudais_192kbps.wav done.
# 001001_Abdullah_Basfar_32kbps.wav done.
# 001003_Abdul_Basit_Mujawwad_128kbps.wav done.
# 001001_Alafasy_128kbps.wav done.
# 001002_Abdul_Basit_Mujawwad_128kbps.wav done.
# 001004_Alafasy_128kbps.wav done.
# 001007_Abdullah_Basfar_32kbps.wav done.
# 001002_Ali_Hajjaj_AlSuesy_128kbps.wav done.
# 001006_ahmed_ibn_ali_al_ajamy_128kbps.wav done.
# 001006_Abdul_Basit_Mujawwad_128kbps.wav done.
# 001000_Abdul_Basit_Mujawwad_128kbps.wav done.
# 001007_aziz_alili_128kbps.wav done.
# 001002_Abu_Bakr_Ash-Shaatree_128kbps.wav done.
# 001003_Abu_Bakr_Ash-Shaatree_64kbps.wav done.
# 001001_Alafasy_64kbps.wav done.
# 001002_Ahmed_ibn_Ali_al-Ajamy_64kbps.wav done.
# 001005_Abu_Bakr_Ash-Shaatree_128kbps.wav done.
# 001007_Abdurrahmaan_As-Sudais_192kbps.wav done.
# 001005_Abdurrahmaan_As-Sudais_192kbps.wav done.
# 001000_Abdul_Basit_Murattal_192kbps.wav done.
# 001003_Abdullaah_3awwaad_Al-Juhaynee_128kbps.wav done.
# 001004_aziz_alili_128kbps.wav done.
# 001007_Abdullaah_3awwaad_Al-Juhaynee_128kbps.wav done.
# 001004_Ahmed_Neana_128kbps.wav done.
# 001004_Ahmed_ibn_Ali_al-Ajamy_128kbps.wav done.
# 001004_Ahmed_ibn_Ali_al-Ajamy_64kbps.wav done.
# 001000_Abu_Bakr_Ash-Shaatree_128kbps.wav done.

# %%
batchs = list()
for i in range(1, len(MFCCS)+1):
    if len(MFCCS) % i == 0:
        batchs.append(i)
print(batchs)
BATCH = int(input("Please choose a batch size: "))
if BATCH not in batchs:
    print("Choosen batch size: %d" % len(MFCCS))
# Out:
# [1, 2, 4, 41, 82, 164]
# Please choose a batch size: 164

# %%
net = tflearn.input_data([None, 20, 2149])
net = tflearn.lstm(net, 128, dropout=0.8)
net = tflearn.fully_connected(net, 164, activation='softmax')
net = tflearn.regression(net, optimizer='adam', learning_rate=0.0001, loss='categorical_crossentropy')

# %%
model = tflearn.DNN(net, tensorboard_verbose=0)
model.fit(MFCCS, LABELS, n_epoch=3000, validation_set=(MFCCS, LABELS), show_metric=True, batch_size=BATCH)
model.save("tflearn.lstm.model")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-2e2c55ad1298> in <module>()
#       1 model = tflearn.DNN(net, tensorboard_verbose=0)
# ----> 2 model.fit(MFCCS, LABELS, n_epoch=3000, validation_set=(MFCCS, LABELS), show_metric=True, batch_size=BATCH)
#       3 model.save("tflearn.lstm.model")
#
# /home/sandimulyadi/.local/lib/python2.7/site-packages/tflearn/models/dnn.pyc in fit(self, X_inputs, Y_targets, n_epoch, validation_set, show_metric, batch_size, shuffle, snapshot_epoch, snapshot_step, excl_trainops, validation_batch_size, run_id, callbacks)
#     182         # TODO: check memory impact for large data and multiple optimizers
#     183         feed_dict = feed_dict_builder(X_inputs, Y_targets, self.inputs,
# --> 184                                       self.targets)
#     185         feed_dicts = [feed_dict for i in self.train_ops]
#     186         val_feed_dicts = None
#
# /home/sandimulyadi/.local/lib/python2.7/site-packages/tflearn/utils.pyc in feed_dict_builder(X, Y, net_inputs, net_targets)
#     281                 X = [X]
#     282             for i, x in enumerate(X):
# --> 283                 feed_dict[net_inputs[i]] = x
#     284         else:
#     285             # If a dict is provided
#
# IndexError: list index out of range
