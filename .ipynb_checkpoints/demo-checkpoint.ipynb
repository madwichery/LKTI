# %% [markdown]
# # DEMO

# %%
from IPython.display import Video
import os
import librosa
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
import IPython

# %%
Video('test.mp4')
# Out:
# <video src="test.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
print('001001_test_a.wav')
IPython.display.display(IPython.display.Audio('./dataset/sudais/test/001001_test_a.wav'))
y, sr = librosa.load('./dataset/sudais/test/001001_test_a.wav', sr=None, mono=True)
plt.figure(figsize=(14,5))
librosa.display.waveplot(y, sr=sr)
print('\n')
# Out:
# 001001_test_a.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('001003_test_b.wav')
IPython.display.display(IPython.display.Audio('./dataset/sudais/test/001003_test_b.wav'))
y, sr = librosa.load('./dataset/sudais/test/001003_test_b.wav', sr=None, mono=True)
plt.figure(figsize=(14,5))
librosa.display.waveplot(y, sr=sr)
print('\n')
# Out:
# 001002_test_a.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('001007_test_a.wav')
IPython.display.display(IPython.display.Audio('./dataset/sudais/test/001007_test_a.wav'))
y, sr = librosa.load('./dataset/sudais/test/001007_test_a.wav', sr=None, mono=True)
plt.figure(figsize=(14,5))
librosa.display.waveplot(y, sr=sr)
print('\n')
# Out:
# 001003_test_a.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # HASIL

# %% [markdown]
# 001001_test_a.wav
# 3 : 0.5572211146
#
# 001003_test_b.wav
# 3 : 0.8391079903
#
# 001006_test_b.wav
# 6 : 0.2856423259
#
# 001004_test_b.wav
# 4 : 0.7824631929
#
# 001007_test_b.wav
# 7 : 0.9545349479
#
# 001007_test_a.wav
# 7 : 0.9620249867
